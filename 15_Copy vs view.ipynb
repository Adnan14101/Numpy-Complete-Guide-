# %% [markdown]
# # Copy Vs View

# %% [markdown]
# ## Copy

# %%
import numpy as np
var = np.array([1, 2, 3, 4])
co = var.copy()

print("var :", var)
print("copy :", co)
# Out:
# var : [1 2 3 4]
# copy : [1 2 3 4]

# %% [markdown]
# ## View

# %%
x = np.array([9, 8, 7, 6])
vi = x.view()
print("X :", x)
print("View :", vi)
# Out:
# X : [9 8 7 6]
# View : [9 8 7 6]
