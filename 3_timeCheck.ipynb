# %%
# %timeit [j**4 for j in range (1, 9)]
# Out:
# 563 ns ± 11.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as np
# %timeit np.arange (1, 9)**4
# Out:
# 1.62 μs ± 42.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
